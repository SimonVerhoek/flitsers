# %%
import pandas as pd
import dask.dataframe as dd
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import cross_val_score
import graphviz

from py.consts import DATA_DIR


initial_sample_size = 1000

# %%
num_partitions = 4
parquet_files = [f"/Users/simonverhoek/Documents/programming/projects/flitsers/notebook/data/partition_{i}.parquet" for i in range(4)]
print(parquet_files)
# Out:
# ['/Users/simonverhoek/Documents/programming/projects/flitsers/notebook/data/partition_0.parquet', '/Users/simonverhoek/Documents/programming/projects/flitsers/notebook/data/partition_1.parquet', '/Users/simonverhoek/Documents/programming/projects/flitsers/notebook/data/partition_2.parquet', '/Users/simonverhoek/Documents/programming/projects/flitsers/notebook/data/partition_3.parquet']

# %%
data = pd.read_parquet(DATA_DIR / f"encoded_test.parquet")

print(f"{len(data)} rows")
data.head()
# Out:
# 4385206 rows
#                      y  zijde_links  zijde_rechts  month_August  \
# __null_dask_index__
# 53100                1            0             1             0
# 91510                1            0             0             0
# 50223                1            0             1             0
# 4439                 1            0             0             0
# 34728                1            0             0             0
#
#                      month_December  month_February  month_January  \
# __null_dask_index__
# 53100                             0               0              1
# 91510                             1               0              0
# 50223                             0               0              0
# 4439                              0               0              0
# 34728                             0               0              0
#
#                      month_July  month_June  month_March  ...  stop_hour_14  \
# __null_dask_index__                                       ...
# 53100                         0           0            0  ...             0
# 91510                         0           0            0  ...             1
# 50223                         0           0            0  ...             0
# 4439                          0           0            0  ...             0
# 34728                         0           1            0  ...             0
#
#                      stop_hour_15  stop_hour_16  stop_hour_17  stop_hour_18  \
# __null_dask_index__
# 53100                           0             0             0             0
# 91510                           0             0             0             0
# 50223                           0             1             0             0
# 4439                            0             0             0             0
# 34728                           0             0             0             1
#
#                      stop_hour_19  stop_hour_20  stop_hour_21  stop_hour_22  \
# __null_dask_index__
# 53100                           0             0             0             0
# 91510                           0             0             0             0
# 50223                           0             0             0             0
# 4439                            0             0             0             0
# 34728                           0             0             0             0
#
#                      stop_hour_23
# __null_dask_index__
# 53100                           0
# 91510                           0
# 50223                           0
# 4439                            1
# 34728                           0
#
# [5 rows x 630 columns]

# %%
X = data.drop("y", axis=1)
y = data[["y"]]

# %%
X_train, X_, y_train, y_ = train_test_split(X, y, test_size=0.4)
X_cv, X_test, y_cv, y_test = train_test_split(X_, y_, test_size=0.50)

print("y_train")
print(f"length: {len(y_train)}")
print(f"positive: {len(y_train[y_train.y == 1])} ({len(y_train[y_train.y == 1]) / len(y_train) * 100:.2f}%) negative: {len(y_train[y_train.y == 0])}")
print()
print("y_")
print(f"length: {len(y_)}")
print(f"positive: {len(y_[y_.y == 1])} ({len(y_[y_.y == 1]) / len(y_) * 100:.2f}%) negative: {len(y_[y_.y == 0])}")
print()
print("y_cv")
print(f"length: {len(y_cv)}")
print(f"positive: {len(y_cv[y_cv.y == 1])} ({len(y_cv[y_cv.y == 1]) / len(y_cv) * 100:.2f}%) negative: {len(y_cv[y_cv.y == 0])}")
print()
print("y_test")
print(f"length: {len(y_test)}")
print(f"positive: {len(y_test[y_test.y == 1])} ({len(y_test[y_test.y == 1]) / len(y_test) * 100:.2f}%) negative: {len(y_test[y_test.y == 0])}")
# Out:
# y_train
# length: 2631123
# positive: 27955 (1.06%) negative: 2603168
#
# y_
# length: 1754083
# positive: 18751 (1.07%) negative: 1735332
#
# y_cv
# length: 877041
# positive: 9370 (1.07%) negative: 867671
#
# y_test
# length: 877042
# positive: 9381 (1.07%) negative: 867661

# %%
"""
DecisiontreeClassifier
"""
# param_grid = {
#     'max_depth': [1, 2, 3],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4]
# }
# 
# grid_search = GridSearchCV(DecisionTreeClassifier(criterion="entropy"), param_grid, cv=2, verbose=3, scoring="accuracy")
# grid_search.fit(X_train, y_train)
"""
RandomForestClassifier
"""
param_grid = {
    'n_estimators': [100, 200, 300],
    "criterion": ["gini", "entropy", "log_loss"],
    'max_depth': [None, 1, 2, 5],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}
# grid_search = GridSearchCV(estimator=RandomForestClassifier(), param_grid=param_grid, scoring="accuracy", cv=3, verbose=3)
# grid_search.fit(X_train, y_train.values.ravel())
# print(grid_search.feature_importances)

clf_model = RandomForestClassifier(n_estimators=100, max_depth=5, min_samples_split=2, min_samples_leaf=2)
clf_model.fit(X_train, y_train.values.ravel())

print("Done training!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 28
#      26 clf_model = RandomForestClassifier(n_estimators=100, max_depth=5, min_samples_split=2, min_samples_leaf=2)
#      27 clf_model.fit(X_train, y_train.values.ravel())
# ---> 28 print(clf_model.feature_importances)
#      30 print("Done training!")
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'feature_importances'

# %%
print(clf_model.feature_names_in_)
print(clf_model.feature_importances_)
# Access the best hyperparameters
print(grid_search.best_params_)
print(grid_search.best_estimator_)
# Out:
# ['zijde_links' 'zijde_rechts' 'month_August' 'month_December'
#  'month_February' 'month_January' 'month_July' 'month_June' 'month_March'
#  'month_May' 'month_November' 'month_October' 'month_September'
#  'day_Monday' 'day_Saturday' 'day_Sunday' 'day_Thursday' 'day_Tuesday'
#  'day_Wednesday' 'wegnummer_A10' 'wegnummer_A12' 'wegnummer_A13'
#  'wegnummer_A15' 'wegnummer_A16' 'wegnummer_A17' 'wegnummer_A18'
#  'wegnummer_A2' 'wegnummer_A20' 'wegnummer_A200' 'wegnummer_A208'
#  'wegnummer_A22' 'wegnummer_A256' 'wegnummer_A27' 'wegnummer_A270'
#  'wegnummer_A28' 'wegnummer_A29' 'wegnummer_A30' 'wegnummer_A31'
#  'wegnummer_A32' 'wegnummer_A325' 'wegnummer_A326' 'wegnummer_A348'
#  'wegnummer_A35' 'wegnummer_A37' 'wegnummer_A4' 'wegnummer_A44'
#  'wegnummer_A5' 'wegnummer_A50' 'wegnummer_A58' 'wegnummer_A59'
#  'wegnummer_A6' 'wegnummer_A65' 'wegnummer_A67' 'wegnummer_A7'
#  'wegnummer_A73' 'wegnummer_A74' 'wegnummer_A76' 'wegnummer_A77'
#  'wegnummer_A79' 'wegnummer_A8' 'wegnummer_A9' 'wegnummer_N11'
#  'wegnummer_N14' 'wegnummer_N15' 'wegnummer_N18' 'wegnummer_N196'
#  'wegnummer_N197' 'wegnummer_N198' 'wegnummer_N199' 'wegnummer_N2'
#  'wegnummer_N200' 'wegnummer_N201' 'wegnummer_N202' 'wegnummer_N203'
#  'wegnummer_N204' 'wegnummer_N205' 'wegnummer_N206' 'wegnummer_N207'
#  'wegnummer_N208' 'wegnummer_N209' 'wegnummer_N210' 'wegnummer_N211'
#  'wegnummer_N212' 'wegnummer_N213' 'wegnummer_N214' 'wegnummer_N215'
#  'wegnummer_N216' 'wegnummer_N217' 'wegnummer_N218' 'wegnummer_N219'
#  'wegnummer_N221' 'wegnummer_N222' 'wegnummer_N223' 'wegnummer_N224'
#  'wegnummer_N225' 'wegnummer_N226' 'wegnummer_N227' 'wegnummer_N228'
#  'wegnummer_N229' 'wegnummer_N230' 'wegnummer_N231' 'wegnummer_N232'
#  'wegnummer_N233' 'wegnummer_N234' 'wegnummer_N235' 'wegnummer_N236'
#  'wegnummer_N237' 'wegnummer_N238' 'wegnummer_N239' 'wegnummer_N240'
#  'wegnummer_N241' 'wegnummer_N242' 'wegnummer_N243' 'wegnummer_N244'
#  'wegnummer_N245' 'wegnummer_N246' 'wegnummer_N247' 'wegnummer_N248'
#  'wegnummer_N249' 'wegnummer_N250' 'wegnummer_N251' 'wegnummer_N252'
#  'wegnummer_N253' 'wegnummer_N254' 'wegnummer_N255' 'wegnummer_N256'
#  'wegnummer_N257' 'wegnummer_N258' 'wegnummer_N259' 'wegnummer_N260'
#  'wegnummer_N261' 'wegnummer_N262' 'wegnummer_N263' 'wegnummer_N264'
#  'wegnummer_N266' 'wegnummer_N267' 'wegnummer_N268' 'wegnummer_N269'
#  'wegnummer_N270' 'wegnummer_N271' 'wegnummer_N272' 'wegnummer_N273'
#  'wegnummer_N274' 'wegnummer_N275' 'wegnummer_N276' 'wegnummer_N277'
#  'wegnummer_N278' 'wegnummer_N279' 'wegnummer_N280' 'wegnummer_N281'
#  'wegnummer_N282' 'wegnummer_N283' 'wegnummer_N284' 'wegnummer_N285'
#  'wegnummer_N286' 'wegnummer_N288' 'wegnummer_N289' 'wegnummer_N290'
#  'wegnummer_N291' 'wegnummer_N292' 'wegnummer_N293' 'wegnummer_N294'
#  'wegnummer_N295' 'wegnummer_N296' 'wegnummer_N297' 'wegnummer_N298'
#  'wegnummer_N299' 'wegnummer_N3' 'wegnummer_N300' 'wegnummer_N301'
#  'wegnummer_N302' 'wegnummer_N303' 'wegnummer_N304' 'wegnummer_N305'
#  'wegnummer_N306' 'wegnummer_N307' 'wegnummer_N308' 'wegnummer_N309'
#  'wegnummer_N31' 'wegnummer_N310' 'wegnummer_N311' 'wegnummer_N312'
#  'wegnummer_N313' 'wegnummer_N314' 'wegnummer_N315' 'wegnummer_N316'
#  'wegnummer_N317' 'wegnummer_N318' 'wegnummer_N319' 'wegnummer_N32'
#  'wegnummer_N320' 'wegnummer_N321' 'wegnummer_N322' 'wegnummer_N323'
#  'wegnummer_N324' 'wegnummer_N325' 'wegnummer_N326' 'wegnummer_N327'
#  'wegnummer_N329' 'wegnummer_N33' 'wegnummer_N330' 'wegnummer_N331'
#  'wegnummer_N332' 'wegnummer_N333' 'wegnummer_N334' 'wegnummer_N335'
#  'wegnummer_N336' 'wegnummer_N337' 'wegnummer_N338' 'wegnummer_N339'
#  'wegnummer_N34' 'wegnummer_N340' 'wegnummer_N341' 'wegnummer_N342'
#  'wegnummer_N343' 'wegnummer_N344' 'wegnummer_N345' 'wegnummer_N346'
#  'wegnummer_N347' 'wegnummer_N348' 'wegnummer_N349' 'wegnummer_N35'
#  'wegnummer_N350' 'wegnummer_N351' 'wegnummer_N352' 'wegnummer_N353'
#  'wegnummer_N354' 'wegnummer_N355' 'wegnummer_N356' 'wegnummer_N357'
#  'wegnummer_N358' 'wegnummer_N359' 'wegnummer_N36' 'wegnummer_N360'
#  'wegnummer_N361' 'wegnummer_N362' 'wegnummer_N363' 'wegnummer_N364'
#  'wegnummer_N365' 'wegnummer_N366' 'wegnummer_N367' 'wegnummer_N369'
#  'wegnummer_N370' 'wegnummer_N371' 'wegnummer_N372' 'wegnummer_N373'
#  'wegnummer_N374' 'wegnummer_N375' 'wegnummer_N376' 'wegnummer_N377'
#  'wegnummer_N378' 'wegnummer_N379' 'wegnummer_N380' 'wegnummer_N381'
#  'wegnummer_N383' 'wegnummer_N384' 'wegnummer_N385' 'wegnummer_N386'
#  'wegnummer_N387' 'wegnummer_N388' 'wegnummer_N389' 'wegnummer_N390'
#  'wegnummer_N391' 'wegnummer_N392' 'wegnummer_N393' 'wegnummer_N394'
#  'wegnummer_N395' 'wegnummer_N396' 'wegnummer_N397' 'wegnummer_N398'
#  'wegnummer_N401' 'wegnummer_N402' 'wegnummer_N403' 'wegnummer_N404'
#  'wegnummer_N405' 'wegnummer_N408' 'wegnummer_N409' 'wegnummer_N411'
#  'wegnummer_N412' 'wegnummer_N413' 'wegnummer_N414' 'wegnummer_N415'
#  'wegnummer_N416' 'wegnummer_N417' 'wegnummer_N419' 'wegnummer_N44'
#  'wegnummer_N440' 'wegnummer_N441' 'wegnummer_N442' 'wegnummer_N443'
#  'wegnummer_N444' 'wegnummer_N445' 'wegnummer_N446' 'wegnummer_N447'
#  'wegnummer_N449' 'wegnummer_N451' 'wegnummer_N452' 'wegnummer_N453'
#  'wegnummer_N455' 'wegnummer_N456' 'wegnummer_N457' 'wegnummer_N458'
#  'wegnummer_N459' 'wegnummer_N46' 'wegnummer_N460' 'wegnummer_N461'
#  'wegnummer_N462' 'wegnummer_N463' 'wegnummer_N464' 'wegnummer_N466'
#  'wegnummer_N468' 'wegnummer_N470' 'wegnummer_N471' 'wegnummer_N472'
#  'wegnummer_N473' 'wegnummer_N475' 'wegnummer_N476' 'wegnummer_N48'
#  'wegnummer_N480' 'wegnummer_N481' 'wegnummer_N482' 'wegnummer_N484'
#  'wegnummer_N487' 'wegnummer_N488' 'wegnummer_N489' 'wegnummer_N491'
#  'wegnummer_N492' 'wegnummer_N493' 'wegnummer_N494' 'wegnummer_N495'
#  'wegnummer_N496' 'wegnummer_N497' 'wegnummer_N498' 'wegnummer_N50'
#  'wegnummer_N501' 'wegnummer_N502' 'wegnummer_N504' 'wegnummer_N506'
#  'wegnummer_N507' 'wegnummer_N508' 'wegnummer_N509' 'wegnummer_N510'
#  'wegnummer_N512' 'wegnummer_N513' 'wegnummer_N514' 'wegnummer_N515'
#  'wegnummer_N516' 'wegnummer_N517' 'wegnummer_N518' 'wegnummer_N519'
#  'wegnummer_N520' 'wegnummer_N521' 'wegnummer_N522' 'wegnummer_N524'
#  'wegnummer_N525' 'wegnummer_N526' 'wegnummer_N527' 'wegnummer_N551'
#  'wegnummer_N552' 'wegnummer_N554' 'wegnummer_N556' 'wegnummer_N560'
#  'wegnummer_N562' 'wegnummer_N564' 'wegnummer_N566' 'wegnummer_N57'
#  'wegnummer_N570' 'wegnummer_N572' 'wegnummer_N584' 'wegnummer_N59'
#  'wegnummer_N590' 'wegnummer_N591' 'wegnummer_N595' 'wegnummer_N597'
#  'wegnummer_N598' 'wegnummer_N60' 'wegnummer_N602' 'wegnummer_N603'
#  'wegnummer_N604' 'wegnummer_N605' 'wegnummer_N608' 'wegnummer_N61'
#  'wegnummer_N611' 'wegnummer_N612' 'wegnummer_N613' 'wegnummer_N614'
#  'wegnummer_N615' 'wegnummer_N616' 'wegnummer_N617' 'wegnummer_N618'
#  'wegnummer_N619' 'wegnummer_N62' 'wegnummer_N620' 'wegnummer_N622'
#  'wegnummer_N624' 'wegnummer_N625' 'wegnummer_N626' 'wegnummer_N630'
#  'wegnummer_N631' 'wegnummer_N632' 'wegnummer_N636' 'wegnummer_N637'
#  'wegnummer_N638' 'wegnummer_N639' 'wegnummer_N640' 'wegnummer_N65'
#  'wegnummer_N653' 'wegnummer_N654' 'wegnummer_N655' 'wegnummer_N656'
#  'wegnummer_N659' 'wegnummer_N661' 'wegnummer_N662' 'wegnummer_N663'
#  'wegnummer_N664' 'wegnummer_N665' 'wegnummer_N666' 'wegnummer_N668'
#  'wegnummer_N669' 'wegnummer_N670' 'wegnummer_N674' 'wegnummer_N677'
#  'wegnummer_N682' 'wegnummer_N683' 'wegnummer_N689' 'wegnummer_N69'
#  'wegnummer_N690' 'wegnummer_N7' 'wegnummer_N701' 'wegnummer_N702'
#  'wegnummer_N703' 'wegnummer_N704' 'wegnummer_N705' 'wegnummer_N706'
#  'wegnummer_N707' 'wegnummer_N708' 'wegnummer_N709' 'wegnummer_N710'
#  'wegnummer_N711' 'wegnummer_N712' 'wegnummer_N713' 'wegnummer_N714'
#  'wegnummer_N715' 'wegnummer_N716' 'wegnummer_N717' 'wegnummer_N720'
#  'wegnummer_N731' 'wegnummer_N732' 'wegnummer_N733' 'wegnummer_N734'
#  'wegnummer_N735' 'wegnummer_N736' 'wegnummer_N737' 'wegnummer_N738'
#  'wegnummer_N739' 'wegnummer_N740' 'wegnummer_N741' 'wegnummer_N742'
#  'wegnummer_N743' 'wegnummer_N744' 'wegnummer_N745' 'wegnummer_N746'
#  'wegnummer_N748' 'wegnummer_N749' 'wegnummer_N750' 'wegnummer_N751'
#  'wegnummer_N752' 'wegnummer_N753' 'wegnummer_N754' 'wegnummer_N755'
#  'wegnummer_N756' 'wegnummer_N757' 'wegnummer_N758' 'wegnummer_N759'
#  'wegnummer_N760' 'wegnummer_N761' 'wegnummer_N762' 'wegnummer_N763'
#  'wegnummer_N764' 'wegnummer_N765' 'wegnummer_N766' 'wegnummer_N781'
#  'wegnummer_N782' 'wegnummer_N783' 'wegnummer_N784' 'wegnummer_N785'
#  'wegnummer_N786' 'wegnummer_N787' 'wegnummer_N788' 'wegnummer_N789'
#  'wegnummer_N790' 'wegnummer_N791' 'wegnummer_N792' 'wegnummer_N793'
#  'wegnummer_N794' 'wegnummer_N795' 'wegnummer_N796' 'wegnummer_N797'
#  'wegnummer_N798' 'wegnummer_N800' 'wegnummer_N801' 'wegnummer_N802'
#  'wegnummer_N803' 'wegnummer_N804' 'wegnummer_N805' 'wegnummer_N806'
#  'wegnummer_N810' 'wegnummer_N811' 'wegnummer_N812' 'wegnummer_N813'
#  'wegnummer_N814' 'wegnummer_N815' 'wegnummer_N816' 'wegnummer_N818'
#  'wegnummer_N819' 'wegnummer_N820' 'wegnummer_N821' 'wegnummer_N822'
#  'wegnummer_N823' 'wegnummer_N824' 'wegnummer_N825' 'wegnummer_N826'
#  'wegnummer_N827' 'wegnummer_N830' 'wegnummer_N831' 'wegnummer_N832'
#  'wegnummer_N833' 'wegnummer_N834' 'wegnummer_N835' 'wegnummer_N836'
#  'wegnummer_N837' 'wegnummer_N839' 'wegnummer_N840' 'wegnummer_N841'
#  'wegnummer_N842' 'wegnummer_N844' 'wegnummer_N845' 'wegnummer_N846'
#  'wegnummer_N847' 'wegnummer_N848' 'wegnummer_N851' 'wegnummer_N852'
#  'wegnummer_N853' 'wegnummer_N854' 'wegnummer_N855' 'wegnummer_N856'
#  'wegnummer_N857' 'wegnummer_N858' 'wegnummer_N860' 'wegnummer_N861'
#  'wegnummer_N862' 'wegnummer_N863' 'wegnummer_N865' 'wegnummer_N9'
#  'wegnummer_N910' 'wegnummer_N913' 'wegnummer_N917' 'wegnummer_N918'
#  'wegnummer_N919' 'wegnummer_N924' 'wegnummer_N962' 'wegnummer_N963'
#  'wegnummer_N964' 'wegnummer_N966' 'wegnummer_N969' 'wegnummer_N972'
#  'wegnummer_N976' 'wegnummer_N978' 'wegnummer_N979' 'wegnummer_N980'
#  'wegnummer_N981' 'wegnummer_N983' 'wegnummer_N986' 'wegnummer_N987'
#  'wegnummer_N989' 'wegnummer_N99' 'wegnummer_N992' 'wegnummer_N994'
#  'wegnummer_N995' 'wegnummer_N996' 'wegnummer_N997' 'wegnummer_N999'
#  'wegnummer_Y351' 'start_hour_1' 'start_hour_2' 'start_hour_3'
#  'start_hour_4' 'start_hour_5' 'start_hour_6' 'start_hour_7'
#  'start_hour_8' 'start_hour_9' 'start_hour_10' 'start_hour_11'
#  'start_hour_12' 'start_hour_13' 'start_hour_14' 'start_hour_15'
#  'start_hour_16' 'start_hour_17' 'start_hour_18' 'start_hour_19'
#  'start_hour_20' 'start_hour_21' 'start_hour_22' 'start_hour_23'
#  'stop_hour_1' 'stop_hour_2' 'stop_hour_3' 'stop_hour_4' 'stop_hour_5'
#  'stop_hour_6' 'stop_hour_7' 'stop_hour_8' 'stop_hour_9' 'stop_hour_10'
#  'stop_hour_11' 'stop_hour_12' 'stop_hour_13' 'stop_hour_14'
#  'stop_hour_15' 'stop_hour_16' 'stop_hour_17' 'stop_hour_18'
#  'stop_hour_19' 'stop_hour_20' 'stop_hour_21' 'stop_hour_22'
#  'stop_hour_23']
# [4.03629039e-04 2.64312669e-04 7.45187771e-06 2.43015344e-05
#  2.69033407e-05 2.38768033e-05 2.05355562e-05 3.23032968e-05
#  2.72476525e-05 1.99049141e-05 1.02023119e-05 1.19986569e-05
#  2.25636491e-05 3.31342846e-05 2.92021175e-05 5.04563699e-05
#  2.02142168e-05 5.06011360e-05 2.12107222e-05 4.13167525e-05
#  4.95022406e-04 4.27114510e-05 2.01795142e-04 3.01428567e-04
#  2.66212771e-06 0.00000000e+00 8.84129508e-04 1.05572454e-06
#  7.36631996e-06 0.00000000e+00 1.54233993e-06 0.00000000e+00
#  1.89682216e-04 2.22221909e-06 2.56212913e-05 1.21924684e-05
#  4.73796868e-06 1.12769190e-06 8.56942291e-07 1.11044186e-07
#  0.00000000e+00 0.00000000e+00 4.28290534e-06 6.80040850e-07
#  2.03213293e-04 4.21756277e-07 1.80857107e-06 3.04483424e-05
#  2.72211908e-05 2.91997247e-07 2.12380591e-04 0.00000000e+00
#  4.49848174e-05 3.25234781e-04 6.87158116e-05 0.00000000e+00
#  3.42597225e-07 8.30642858e-06 6.47309574e-07 1.13121547e-05
#  6.47795098e-05 2.85752088e-06 3.94100001e-06 0.00000000e+00
#  2.46746286e-06 1.25304414e-06 0.00000000e+00 0.00000000e+00
#  1.82480293e-06 9.67186597e-06 5.63164561e-06 2.32191920e-05
#  1.97867798e-07 4.53026994e-05 2.17497920e-06 1.21628841e-05
#  6.96975129e-06 2.73558227e-05 7.22679116e-06 1.37673603e-04
#  9.74769824e-06 5.82940097e-06 1.06121296e-05 1.37373260e-06
#  3.27268678e-05 3.02671028e-05 0.00000000e+00 2.30107214e-05
#  2.04779411e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 3.36518212e-04 0.00000000e+00 3.03540679e-07
#  3.75409794e-07 4.51874447e-06 2.72058750e-06 1.17896052e-05
#  5.37864220e-06 4.29892733e-06 4.13742572e-07 0.00000000e+00
#  0.00000000e+00 3.19775929e-06 3.74097238e-06 0.00000000e+00
#  0.00000000e+00 1.67556504e-06 4.98497852e-06 3.71038378e-05
#  0.00000000e+00 2.15975346e-06 3.70072357e-06 0.00000000e+00
#  4.11007023e-06 0.00000000e+00 0.00000000e+00 3.85137630e-07
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 3.75799126e-06 1.61721426e-06 0.00000000e+00
#  0.00000000e+00 2.40154201e-05 5.49318918e-05 0.00000000e+00
#  0.00000000e+00 2.20925241e-06 2.49030720e-06 2.58359788e-06
#  0.00000000e+00 0.00000000e+00 8.16570444e-07 0.00000000e+00
#  0.00000000e+00 5.92743191e-06 0.00000000e+00 3.89986168e-06
#  9.07452567e-06 9.87380632e-06 6.40574677e-06 1.24383469e-05
#  9.61437046e-06 0.00000000e+00 4.13939029e-06 0.00000000e+00
#  0.00000000e+00 9.77096838e-06 0.00000000e+00 0.00000000e+00
#  5.46960517e-06 9.10827780e-07 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  6.73620314e-06 0.00000000e+00 1.82481054e-04 0.00000000e+00
#  4.64398047e-06 3.96245657e-05 1.30828440e-05 2.23065298e-05
#  0.00000000e+00 1.21571333e-05 6.95292551e-06 1.01736786e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 5.12451551e-07 0.00000000e+00 1.35262428e-06
#  7.53983281e-06 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.55036661e-06 0.00000000e+00 2.28845840e-06 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 5.25215296e-06 6.06261580e-06
#  0.00000000e+00 1.33466743e-05 0.00000000e+00 0.00000000e+00
#  8.34666857e-06 0.00000000e+00 9.75228122e-07 3.01406473e-06
#  3.67961645e-07 0.00000000e+00 0.00000000e+00 6.76004392e-06
#  0.00000000e+00 0.00000000e+00 4.54838902e-06 2.40506580e-05
#  0.00000000e+00 6.46757174e-06 1.50424624e-05 1.65616054e-05
#  0.00000000e+00 7.07675834e-05 3.90099653e-07 3.57313673e-07
#  4.93232252e-06 0.00000000e+00 0.00000000e+00 2.77142011e-06
#  1.53881230e-06 0.00000000e+00 7.34853965e-07 8.53192296e-06
#  3.27987306e-05 3.70875526e-06 1.61162351e-05 1.76098945e-06
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 7.61473106e-07
#  0.00000000e+00 0.00000000e+00 1.32969489e-05 3.81633257e-06
#  0.00000000e+00 3.65608625e-06 6.69208410e-06 1.04632615e-05
#  0.00000000e+00 5.20905498e-05 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.41747305e-06 2.29918658e-06
#  0.00000000e+00 2.82052451e-06 0.00000000e+00 1.99772098e-06
#  4.29872102e-07 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.43397836e-05 0.00000000e+00 2.10300543e-06 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.17788756e-06
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 7.64580017e-06
#  0.00000000e+00 2.86475486e-05 1.40302468e-05 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.33311073e-05 1.26813444e-06 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 3.36503818e-06 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.04653321e-04
#  0.00000000e+00 0.00000000e+00 1.49256389e-06 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.25635800e-07
#  5.48630573e-06 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 3.75816562e-06 6.31344576e-06 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.00887415e-06 0.00000000e+00
#  0.00000000e+00 1.03492854e-07 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.72965941e-05 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.22729758e-05 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 2.79153237e-06 2.57395621e-06 0.00000000e+00
#  4.37356172e-06 0.00000000e+00 4.30897211e-06 5.91927166e-07
#  0.00000000e+00 4.03708726e-06 1.02862918e-05 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 3.92510974e-05 7.02195876e-07 0.00000000e+00
#  0.00000000e+00 1.49686719e-05 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.55220719e-06 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 3.16785864e-06 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 2.78219790e-06
#  4.85591318e-06 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.48183288e-07 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 5.93050810e-06
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 9.67924190e-07 0.00000000e+00 5.58283079e-05
#  1.54981099e-05 2.78024621e-05 0.00000000e+00 0.00000000e+00
#  8.93457822e-06 7.68195657e-08 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 2.78714164e-06 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.90286086e-06 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.77523949e-06
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.88027342e-06 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 5.85293456e-06 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 3.63582082e-06 1.52207029e-06
#  0.00000000e+00 6.07563636e-06 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.00000452e-05 0.00000000e+00
#  1.11493605e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 5.78933490e-06 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.28167198e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.64147742e-06 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.04741243e-06 0.00000000e+00 0.00000000e+00 3.04754747e-06
#  0.00000000e+00 1.00837507e-06 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  4.13063632e-06 0.00000000e+00 5.36771839e-06 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.14259645e-05 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  6.21299843e-07 0.00000000e+00 2.39983264e-05 1.43987703e-05
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.85731879e-04
#  1.70153576e-02 7.49496355e-02 7.47340459e-02 4.47178765e-02
#  6.24488079e-02 2.04366474e-02 2.13154523e-02 1.56720772e-02
#  1.84483612e-02 3.30987279e-02 1.82811496e-02 3.24330319e-03
#  7.19148435e-04 2.45397935e-03 1.02281953e-03 8.66311741e-05
#  5.02952569e-06 6.15784308e-11 0.00000000e+00 0.00000000e+00
#  1.14700951e-05 0.00000000e+00 5.61408990e-05 5.09242675e-04
#  9.91706660e-05 1.37448543e-03 1.36865727e-03 1.29960225e-03
#  8.53533272e-03 2.46871176e-02 1.54704618e-02 2.74089803e-02
#  3.14136685e-02 1.77130101e-02 2.13677443e-02 4.51429842e-02
#  1.70672417e-02 4.90624055e-02 9.07287766e-02 6.43558330e-02
#  1.66888613e-01]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2 print(clf_model.feature_importances_)
#       3 # Access the best hyperparameters
# ----> 4 print(grid_search.best_params_)
#       5 print(grid_search.best_estimator_)
#
# NameError: name 'grid_search' is not defined

# %%
# clf_model = DecisionTreeClassifier(criterion="entropy", **grid_search.best_params_)
clf_model = grid_search.best_estimator_

# %%
import pickle
with open(DATA_DIR / "model.pkl", "wb") as f:
    pickle.dump(clf_model,f)

# %%
clf_model.fit(X_train, y_train)

# %%
y_predict = clf_model.predict(X_)

# %%
accuracy_score(y_, y_predict)
# Out:
# 0.9920596687842024

# %%
class_names = list([str(v) for v in y.y.unique()])
feature_names = list(X.columns)

# %%
# cross validation
y_cv_predict = clf_model.predict(X_cv)
print(f"cross-validation dataset accuracy: {accuracy_score(y_cv, y_cv_predict)}")

# Generate a classification report
report = classification_report(y_, y_predict)
print("\nClassification Report:\n", report)

# Compute the confusion matrix
cm = confusion_matrix(y_, y_predict)
print("\nConfusion Matrix:\n", cm)

scores = cross_val_score(clf_model, X_train, y_train, cv=2)  # 5-fold cross-validation
print("\nCross-Validation Scores:", scores)
# Out:
# cross-validation dataset accuracy: 0.9919433641072652
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00   1735432
#            1       0.99      0.26      0.41     18651
#
#     accuracy                           0.99   1754083
#    macro avg       0.99      0.63      0.70   1754083
# weighted avg       0.99      0.99      0.99   1754083
#
#
# Confusion Matrix:
#  [[1735386      46]
#  [  13882    4769]]
#
# Cross-Validation Scores: [0.99201938 0.99200645]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

results = pd.DataFrame(grid_search.cv_results_)
pivot_table = results.pivot_table(index='param_max_depth', columns='param_min_samples_split', values='mean_test_score')
sns.heatmap(pivot_table, annot=True, fmt=".3f", cmap="YlGnBu")
plt.xlabel('min_samples_split')
plt.ylabel('max_depth')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       4 results = pd.DataFrame(grid_search.cv_results_)
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
plot_tree(clf_model, feature_names=feature_names, class_names=class_names)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plot_tree(clf_model, feature_names=feature_names, class_names=class_names)
#
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/sklearn/tree/_export.py:211, in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     196 check_is_fitted(decision_tree)
#     198 exporter = _MPLTreeExporter(
#     199     max_depth=max_depth,
#     200     feature_names=feature_names,
#    (...)
#     209     fontsize=fontsize,
#     210 )
# --> 211 return exporter.export(decision_tree, ax=ax)
#
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/sklearn/tree/_export.py:636, in _MPLTreeExporter.export(self, decision_tree, ax)
#     635 def export(self, decision_tree, ax=None):
# --> 636     import matplotlib.pyplot as plt
#     637     from matplotlib.text import Annotation
#     639     if ax is None:
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
target = list([str(v) for v in y.y.unique()])
feature_names = list(X.columns)
dot_data = tree.export_graphviz(clf_model,
                                out_file=None, 
                      feature_names=feature_names,  
                      class_names=target,  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  

graph
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/graphviz/backend/execute.py:79, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      78         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 79     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      80 else:
#
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/graphviz/backend/execute.py:99, in _run_input_lines(cmd, input_lines, kwargs)
#      98 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 99     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#     101     stdin_write = popen.stdin.write
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/subprocess.py:1022, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1019             self.stderr = io.TextIOWrapper(self.stderr,
#    1020                     encoding=encoding, errors=errors)
# -> 1022     self._execute_child(args, executable, preexec_fn, close_fds,
#    1023                         pass_fds, cwd, env,
#    1024                         startupinfo, creationflags, shell,
#    1025                         p2cread, p2cwrite,
#    1026                         c2pread, c2pwrite,
#    1027                         errread, errwrite,
#    1028                         restore_signals,
#    1029                         gid, gids, uid, umask,
#    1030                         start_new_session, process_group)
#    1031 except:
#    1032     # Cleanup if the child failed starting.
#
# File ~/.pyenv/versions/3.11.0/lib/python3.11/subprocess.py:1899, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1898         err_msg = os.strerror(errno_num)
# -> 1899     raise child_exception_type(errno_num, err_msg, err_filename)
#    1900 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: PosixPath('dot')
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/IPython/core/formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
#     976 else:
#
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/graphviz/jupyter_integration.py:98, in JupyterIntegration._repr_mimebundle_(self, include, exclude, **_)
#      96 include = set(include) if include is not None else {self._jupyter_mimetype}
#      97 include -= set(exclude or [])
# ---> 98 return {mimetype: getattr(self, method_name)()
#      99         for mimetype, method_name in MIME_TYPES.items()
#     100         if mimetype in include}
#
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/graphviz/jupyter_integration.py:98, in <dictcomp>(.0)
#      96 include = set(include) if include is not None else {self._jupyter_mimetype}
#      97 include -= set(exclude or [])
# ---> 98 return {mimetype: getattr(self, method_name)()
#      99         for mimetype, method_name in MIME_TYPES.items()
#     100         if mimetype in include}
#
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/graphviz/jupyter_integration.py:112, in JupyterIntegration._repr_image_svg_xml(self)
#     110 def _repr_image_svg_xml(self) -> str:
#     111     """Return the rendered graph as SVG string."""
# --> 112     return self.pipe(format='svg', encoding=SVG_ENCODING)
#
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/graphviz/piping.py:104, in Pipe.pipe(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#      55 def pipe(self,
#      56          format: typing.Optional[str] = None,
#      57          renderer: typing.Optional[str] = None,
#    (...)
#      61          engine: typing.Optional[str] = None,
#      62          encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
#      63     """Return the source piped through the Graphviz layout command.
#      64
#      65     Args:
#    (...)
#     102         '<?xml version='
#     103     """
# --> 104     return self._pipe_legacy(format,
#     105                              renderer=renderer,
#     106                              formatter=formatter,
#     107                              neato_no_op=neato_no_op,
#     108                              quiet=quiet,
#     109                              engine=engine,
#     110                              encoding=encoding)
#
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/graphviz/piping.py:121, in Pipe._pipe_legacy(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     112 @_tools.deprecate_positional_args(supported_number=2)
#     113 def _pipe_legacy(self,
#     114                  format: typing.Optional[str] = None,
#    (...)
#     119                  engine: typing.Optional[str] = None,
#     120                  encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
# --> 121     return self._pipe_future(format,
#     122                              renderer=renderer,
#     123                              formatter=formatter,
#     124                              neato_no_op=neato_no_op,
#     125                              quiet=quiet,
#     126                              engine=engine,
#     127                              encoding=encoding)
#
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/graphviz/piping.py:149, in Pipe._pipe_future(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     146 if encoding is not None:
#     147     if codecs.lookup(encoding) is codecs.lookup(self.encoding):
#     148         # common case: both stdin and stdout need the same encoding
# --> 149         return self._pipe_lines_string(*args, encoding=encoding, **kwargs)
#     150     try:
#     151         raw = self._pipe_lines(*args, input_encoding=self.encoding, **kwargs)
#
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/graphviz/backend/piping.py:212, in pipe_lines_string(engine, format, input_lines, encoding, renderer, formatter, neato_no_op, quiet)
#     206 cmd = dot_command.command(engine, format,
#     207                           renderer=renderer,
#     208                           formatter=formatter,
#     209                           neato_no_op=neato_no_op)
#     210 kwargs = {'input_lines': input_lines, 'encoding': encoding}
# --> 212 proc = execute.run_check(cmd, capture_output=True, quiet=quiet, **kwargs)
#     213 return proc.stdout
#
# File ~/Documents/programming/projects/flitsers/venv/lib/python3.11/site-packages/graphviz/backend/execute.py:84, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      82 except OSError as e:
#      83     if e.errno == errno.ENOENT:
# ---> 84         raise ExecutableNotFound(cmd) from e
#      85     raise
#      87 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute PosixPath('dot'), make sure the Graphviz executables are on your systems' PATH

# %%
from sklearn.tree import export_text
r = export_text(clf_model, feature_names=feature_names)
print(r)
# Out:
# |--- stop_hour_23 <= 0.50
# |   |--- start_hour_8 <= 0.50
# |   |   |--- start_hour_9 <= 0.50
# |   |   |   |--- start_hour_10 <= 0.50
# |   |   |   |   |--- start_hour_15 <= 0.50
# |   |   |   |   |   |--- start_hour_14 <= 0.50
# |   |   |   |   |   |   |--- start_hour_11 <= 0.50
# |   |   |   |   |   |   |   |--- start_hour_7 <= 0.50
# |   |   |   |   |   |   |   |   |--- start_hour_13 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- start_hour_16 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- start_hour_16 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- start_hour_13 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- start_hour_7 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- start_hour_11 >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- start_hour_14 >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- start_hour_15 >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- start_hour_10 >  0.50
# |   |   |   |   |--- class: 1
# |   |   |--- start_hour_9 >  0.50
# |   |   |   |--- class: 1
# |   |--- start_hour_8 >  0.50
# |   |   |--- class: 1
# |--- stop_hour_23 >  0.50
# |   |--- start_hour_6 <= 0.50
# |   |   |--- start_hour_18 <= 0.50
# |   |   |   |--- start_hour_19 <= 0.50
# |   |   |   |   |--- start_hour_20 <= 0.50
# |   |   |   |   |   |--- start_hour_21 <= 0.50
# |   |   |   |   |   |   |--- start_hour_17 <= 0.50
# |   |   |   |   |   |   |   |--- start_hour_8 <= 0.50
# |   |   |   |   |   |   |   |   |--- start_hour_7 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- start_hour_9 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- start_hour_9 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- start_hour_7 >  0.50
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N263 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N263 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- start_hour_8 >  0.50
# |   |   |   |   |   |   |   |   |--- wegnummer_N260 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N257 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N257 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- wegnummer_N260 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- start_hour_17 >  0.50
# |   |   |   |   |   |   |   |--- zijde_links <= 0.50
# |   |   |   |   |   |   |   |   |--- zijde_rechts <= 0.50
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N240 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N240 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- zijde_rechts >  0.50
# |   |   |   |   |   |   |   |   |   |--- month_May <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- month_May >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- zijde_links >  0.50
# |   |   |   |   |   |   |   |   |--- month_October <= 0.50
# |   |   |   |   |   |   |   |   |   |--- wegnummer_A37 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- wegnummer_A37 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- month_October >  0.50
# |   |   |   |   |   |   |   |   |   |--- day_Monday <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- day_Monday >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- start_hour_21 >  0.50
# |   |   |   |   |   |   |--- month_October <= 0.50
# |   |   |   |   |   |   |   |--- wegnummer_N244 <= 0.50
# |   |   |   |   |   |   |   |   |--- month_May <= 0.50
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N46 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N46 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- month_May >  0.50
# |   |   |   |   |   |   |   |   |   |--- day_Monday <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- day_Monday >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- wegnummer_N244 >  0.50
# |   |   |   |   |   |   |   |   |--- day_Saturday <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- day_Saturday >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- month_October >  0.50
# |   |   |   |   |   |   |   |--- wegnummer_N203 <= 0.50
# |   |   |   |   |   |   |   |   |--- day_Wednesday <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- day_Wednesday >  0.50
# |   |   |   |   |   |   |   |   |   |--- zijde_rechts <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- zijde_rechts >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- wegnummer_N203 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- start_hour_20 >  0.50
# |   |   |   |   |   |--- day_Monday <= 0.50
# |   |   |   |   |   |   |--- wegnummer_N370 <= 0.50
# |   |   |   |   |   |   |   |--- month_October <= 0.50
# |   |   |   |   |   |   |   |   |--- wegnummer_A9 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N764 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N764 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- wegnummer_A9 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- month_October >  0.50
# |   |   |   |   |   |   |   |   |--- day_Tuesday <= 0.50
# |   |   |   |   |   |   |   |   |   |--- zijde_rechts <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- zijde_rechts >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- day_Tuesday >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- wegnummer_N370 >  0.50
# |   |   |   |   |   |   |   |--- day_Saturday <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- day_Saturday >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- day_Monday >  0.50
# |   |   |   |   |   |   |--- wegnummer_N245 <= 0.50
# |   |   |   |   |   |   |   |--- wegnummer_N36 <= 0.50
# |   |   |   |   |   |   |   |   |--- wegnummer_N361 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N46 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N46 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- wegnummer_N361 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- wegnummer_N36 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- wegnummer_N245 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- start_hour_19 >  0.50
# |   |   |   |   |--- wegnummer_N242 <= 0.50
# |   |   |   |   |   |--- day_Sunday <= 0.50
# |   |   |   |   |   |   |--- month_December <= 0.50
# |   |   |   |   |   |   |   |--- wegnummer_N377 <= 0.50
# |   |   |   |   |   |   |   |   |--- wegnummer_N370 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- wegnummer_A27 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- wegnummer_A27 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- wegnummer_N370 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- wegnummer_N377 >  0.50
# |   |   |   |   |   |   |   |   |--- day_Wednesday <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- day_Wednesday >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- month_December >  0.50
# |   |   |   |   |   |   |   |--- day_Wednesday <= 0.50
# |   |   |   |   |   |   |   |   |--- day_Monday <= 0.50
# |   |   |   |   |   |   |   |   |   |--- day_Tuesday <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- day_Tuesday >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- day_Monday >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- day_Wednesday >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- day_Sunday >  0.50
# |   |   |   |   |   |   |--- month_August <= 0.50
# |   |   |   |   |   |   |   |--- month_October <= 0.50
# |   |   |   |   |   |   |   |   |--- zijde_rechts <= 0.50
# |   |   |   |   |   |   |   |   |   |--- month_September <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- month_September >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- zijde_rechts >  0.50
# |   |   |   |   |   |   |   |   |   |--- wegnummer_A2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- wegnummer_A2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- month_October >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- month_August >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- wegnummer_N242 >  0.50
# |   |   |   |   |   |--- day_Thursday <= 0.50
# |   |   |   |   |   |   |--- day_Wednesday <= 0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- day_Wednesday >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- day_Thursday >  0.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- start_hour_18 >  0.50
# |   |   |   |--- wegnummer_N506 <= 0.50
# |   |   |   |   |--- wegnummer_A7 <= 0.50
# |   |   |   |   |   |--- month_February <= 0.50
# |   |   |   |   |   |   |--- wegnummer_A4 <= 0.50
# |   |   |   |   |   |   |   |--- wegnummer_N203 <= 0.50
# |   |   |   |   |   |   |   |   |--- wegnummer_N307 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N33 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N33 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- wegnummer_N307 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- wegnummer_N203 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- wegnummer_A4 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- month_February >  0.50
# |   |   |   |   |   |   |--- wegnummer_N242 <= 0.50
# |   |   |   |   |   |   |   |--- wegnummer_N702 <= 0.50
# |   |   |   |   |   |   |   |   |--- wegnummer_A2 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- wegnummer_A28 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- wegnummer_A28 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- wegnummer_A2 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- wegnummer_N702 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- wegnummer_N242 >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- wegnummer_A7 >  0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- wegnummer_N506 >  0.50
# |   |   |   |   |--- day_Monday <= 0.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- day_Monday >  0.50
# |   |   |   |   |   |--- class: 0
# |   |--- start_hour_6 >  0.50
# |   |   |--- month_September <= 0.50
# |   |   |   |--- zijde_rechts <= 0.50
# |   |   |   |   |--- zijde_links <= 0.50
# |   |   |   |   |   |--- wegnummer_N285 <= 0.50
# |   |   |   |   |   |   |--- wegnummer_N263 <= 0.50
# |   |   |   |   |   |   |   |--- wegnummer_N257 <= 0.50
# |   |   |   |   |   |   |   |   |--- day_Saturday <= 0.50
# |   |   |   |   |   |   |   |   |   |--- month_October <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- month_October >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- day_Saturday >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- wegnummer_N257 >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- wegnummer_N263 >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- wegnummer_N285 >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- zijde_links >  0.50
# |   |   |   |   |   |--- month_March <= 0.50
# |   |   |   |   |   |   |--- day_Tuesday <= 0.50
# |   |   |   |   |   |   |   |--- day_Wednesday <= 0.50
# |   |   |   |   |   |   |   |   |--- day_Thursday <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- day_Thursday >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- day_Wednesday >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- day_Tuesday >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- month_March >  0.50
# |   |   |   |   |   |   |--- wegnummer_A27 <= 0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- wegnummer_A27 >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- zijde_rechts >  0.50
# |   |   |   |   |--- wegnummer_N59 <= 0.50
# |   |   |   |   |   |--- month_March <= 0.50
# |   |   |   |   |   |   |--- month_October <= 0.50
# |   |   |   |   |   |   |   |--- day_Tuesday <= 0.50
# |   |   |   |   |   |   |   |   |--- month_June <= 0.50
# |   |   |   |   |   |   |   |   |   |--- day_Thursday <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- day_Thursday >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- month_June >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- day_Tuesday >  0.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- month_October >  0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- month_March >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- wegnummer_N59 >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- month_September >  0.50
# |   |   |   |--- day_Saturday <= 0.50
# |   |   |   |   |--- zijde_rechts <= 0.50
# |   |   |   |   |   |--- day_Wednesday <= 0.50
# |   |   |   |   |   |   |--- day_Sunday <= 0.50
# |   |   |   |   |   |   |   |--- day_Monday <= 0.50
# |   |   |   |   |   |   |   |   |--- day_Tuesday <= 0.50
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N309 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- wegnummer_N309 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- day_Tuesday >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- day_Monday >  0.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- day_Sunday >  0.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- day_Wednesday >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- zijde_rechts >  0.50
# |   |   |   |   |   |--- day_Thursday <= 0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- day_Thursday >  0.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- day_Saturday >  0.50
# |   |   |   |   |--- class: 1
